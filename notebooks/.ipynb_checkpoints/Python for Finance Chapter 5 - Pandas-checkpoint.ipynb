# %%
import pandas as pd
import os
print(os.environ['IEX_TOKEN'])
# Out:
# pk_2f841cbff2d6422ab0145ada59fa5d34

# %%
df = pd.DataFrame([10,20,30,40], columns=['numbers'], index=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40

# %%
# Cell selection reverse of RC cola - Column then Row by label
df['numbers']['b']
# Out:
# 20

# %%
# get rows
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
# get columns
df.columns
# Out:
# Index(['numbers'], dtype='object')

# %%
# lookup by row id
df.loc['c']
# Out:
# numbers    30
# Name: c, dtype: int64

# %%
df.iloc[1:3] # lookup by row index inclusive to exclusive
# Out:
#    numbers
# b       20
# c       30

# %%
df.loc[['a', 'd']] # multi-lookup single row
# Out:
#    numbers
# a       10
# d       40

# %%
df.sum() # sum per column
# Out:
# numbers    100
# dtype: int64

# %%
df['numbers'].apply(lambda x : x**2) # lambda function on all members of column
# Out:
# a     100
# b     400
# c     900
# d    1600
# Name: numbers, dtype: int64

# %%
df ** 2 # same on whole df
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
# Adding a column - provide a tuple
df['floats'] = (1.5, 2.5, 3.5, 4.5)
df
# Out:
#    numbers  floats
# a       10     1.5
# b       20     2.5
# c       30     3.5
# d       40     4.5

# %%
# add a column by adding a dataframe, specifying index mapping
df['names'] = pd.DataFrame(['Yves', 'Sandra', 'Lilli', 'Henry'], index=['d', 'a', 'b', 'c'])
df
# Out:
#    numbers  floats   names
# a       10     1.5  Sandra
# b       20     2.5   Lilli
# c       30     3.5   Henry
# d       40     4.5    Yves

# %%
# When appending, always include the index, or you lose all indices
df = df.append(pd.DataFrame({'numbers': 50, 'floats': 5.2, 'names': 'Mork'}, index=['y',]))
df
# Out:
#    numbers floats   names
# a       10    1.5  Sandra
# b       20    2.5   Lilli
# c       30    3.5   Henry
# d       40    4.5    Yves
# y       50    5.2    Mork
# y       50    5.2    Mork
# y       50    5.2    Mork

# %%
# Mean of specified columns - ignoring NaN
df[['numbers']].mean()
# Out:
# numbers    35.714286
# dtype: float64

# %%
df[['numbers', 'floats']].std()
# Out:
# numbers    16.183472
# dtype: float64

# %%
import numpy as np

# %%
np.random.seed(100)

# %%
a = np.random.standard_normal((9,4)) # standard normal - mean 0, std 1
a
# Out:
# array([[-0.33177714, -0.68921798,  2.03460756, -0.55071441],
#        [ 0.75045333, -1.30699234,  0.58057334, -1.10452309],
#        [ 0.69012147,  0.68689007, -1.56668753,  0.90497412],
#        [ 0.7788224 ,  0.42823287,  0.10887199,  0.02828363],
#        [-0.57882582, -1.1994512 , -1.70595201,  0.36916396],
#        [ 1.87657343, -0.37690335,  1.83193608,  0.00301743],
#        [-0.07602347,  0.00395759, -0.18501411, -2.48715154],
#        [-1.70465121, -1.13626101, -2.97331547,  0.03331728],
#        [-0.24888867, -0.45017644,  0.1324278 ,  0.02221393]])

# %%
# now make it a DataFrame
df = pd.DataFrame(a)
df
# Out:
#           0         1         2         3
# 0 -0.331777 -0.689218  2.034608 -0.550714
# 1  0.750453 -1.306992  0.580573 -1.104523
# 2  0.690121  0.686890 -1.566688  0.904974
# 3  0.778822  0.428233  0.108872  0.028284
# 4 -0.578826 -1.199451 -1.705952  0.369164
# 5  1.876573 -0.376903  1.831936  0.003017
# 6 -0.076023  0.003958 -0.185014 -2.487152
# 7 -1.704651 -1.136261 -2.973315  0.033317
# 8 -0.248889 -0.450176  0.132428  0.022214

# %%
# Assign columns after df creation
df.columns = ['No. 1', 'No. 2', 'No. 3', 'No. 4']
df
# Out:
#       No. 1     No. 2     No. 3     No. 4
# 0 -0.331777 -0.689218  2.034608 -0.550714
# 1  0.750453 -1.306992  0.580573 -1.104523
# 2  0.690121  0.686890 -1.566688  0.904974
# 3  0.778822  0.428233  0.108872  0.028284
# 4 -0.578826 -1.199451 -1.705952  0.369164
# 5  1.876573 -0.376903  1.831936  0.003017
# 6 -0.076023  0.003958 -0.185014 -2.487152
# 7 -1.704651 -1.136261 -2.973315  0.033317
# 8 -0.248889 -0.450176  0.132428  0.022214

# %%
df['No. 2'].mean() # Run moments per column
# Out:
# -0.44888019751663855

# %%
# Create a time series
dates = pd.date_range('2019-1-1', periods=9, freq='M')
dates
# Out:
# DatetimeIndex(['2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
#                '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#                '2019-09-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
df.index = dates
df # instant time series indexed series
# Out:
#                No. 1     No. 2     No. 3     No. 4
# 2019-01-31 -0.331777 -0.689218  2.034608 -0.550714
# 2019-02-28  0.750453 -1.306992  0.580573 -1.104523
# 2019-03-31  0.690121  0.686890 -1.566688  0.904974
# 2019-04-30  0.778822  0.428233  0.108872  0.028284
# 2019-05-31 -0.578826 -1.199451 -1.705952  0.369164
# 2019-06-30  1.876573 -0.376903  1.831936  0.003017
# 2019-07-31 -0.076023  0.003958 -0.185014 -2.487152
# 2019-08-31 -1.704651 -1.136261 -2.973315  0.033317
# 2019-09-30 -0.248889 -0.450176  0.132428  0.022214

# %%
# Basic datatypes and Moments
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9 entries, 2019-01-31 to 2019-09-30
# Freq: M
# Data columns (total 4 columns):
# No. 1    9 non-null float64
# No. 2    9 non-null float64
# No. 3    9 non-null float64
# No. 4    9 non-null float64
# dtypes: float64(4)
# memory usage: 360.0 bytes

# %%
df.describe()
# Out:
#           No. 1     No. 2     No. 3     No. 4
# count  9.000000  9.000000  9.000000  9.000000
# mean   0.128423 -0.448880 -0.193617 -0.309047
# std    1.026997  0.715849  1.649405  0.987881
# min   -1.704651 -1.306992 -2.973315 -2.487152
# 25%   -0.331777 -1.136261 -1.566688 -0.550714
# 50%   -0.076023 -0.450176  0.108872  0.022214
# 75%    0.750453  0.003958  0.580573  0.033317
# max    1.876573  0.686890  2.034608  0.904974

# %%
# Additionally, you can do these stats column-wise or row-wise
df.sum()
# Out:
# No. 1    1.155804
# No. 2   -4.039922
# No. 3   -1.742552
# No. 4   -2.781419
# dtype: float64

# %%
df.mean()
# Out:
# No. 1    0.128423
# No. 2   -0.448880
# No. 3   -0.193617
# No. 4   -0.309047
# dtype: float64

# %%
df.mean(axis=0) # column-wise
# Out:
# No. 1    0.128423
# No. 2   -0.448880
# No. 3   -0.193617
# No. 4   -0.309047
# dtype: float64

# %%
df.mean(axis=1) # row-wise
# Out:
# 2019-01-31    0.115725
# 2019-02-28   -0.270122
# 2019-03-31    0.178825
# 2019-04-30    0.336053
# 2019-05-31   -0.778766
# 2019-06-30    0.833656
# 2019-07-31   -0.686058
# 2019-08-31   -1.445228
# 2019-09-30   -0.136106
# Freq: M, dtype: float64

# %%
# Finance data time
from datetime import datetime
from iexfinance.stocks import get_historical_data

start = datetime(2019, 1, 1)
end = datetime(2019, 6, 15)
pd.options.display.float_format = '{:,.2f}'.format
df = pd.DataFrame(get_historical_data("AAPL", start, end, close_only=True)).transpose()
df
# Out:
#             close        volume
# 2019-01-02 157.92 37,039,737.00
# 2019-01-03 142.19 91,312,195.00
# 2019-01-04 148.26 58,607,070.00
# 2019-01-07 147.93 54,777,764.00
# 2019-01-08 150.75 41,025,314.00
# 2019-01-09 153.31 45,099,081.00
# 2019-01-10 153.80 35,780,670.00
# 2019-01-11 152.29 27,023,241.00
# 2019-01-14 150.00 32,439,186.00
# 2019-01-15 153.07 28,710,324.00
# 2019-01-16 154.94 30,569,706.00
# 2019-01-17 155.86 29,821,160.00
# 2019-01-18 156.82 33,751,023.00
# 2019-01-22 153.30 30,393,970.00
# 2019-01-23 153.92 23,130,570.00
# 2019-01-24 152.70 25,441,549.00
# 2019-01-25 157.76 33,547,893.00
# 2019-01-28 156.30 26,192,058.00
# 2019-01-29 154.68 41,587,239.00
# 2019-01-30 165.25 61,109,780.00
# 2019-01-31 166.44 40,739,649.00
# 2019-02-01 166.52 32,668,138.00
# 2019-02-04 171.25 31,495,582.00
# 2019-02-05 174.18 36,101,628.00
# 2019-02-06 174.24 28,239,591.00
# 2019-02-07 170.94 31,741,690.00
# 2019-02-08 170.41 23,819,966.00
# 2019-02-11 169.43 20,993,425.00
# 2019-02-12 170.89 22,283,523.00
# 2019-02-13 170.18 22,490,233.00
# ...           ...           ...
# 2019-05-03 211.75 20,892,378.00
# 2019-05-06 208.48 32,443,113.00
# 2019-05-07 202.86 38,763,698.00
# 2019-05-08 202.90 26,339,504.00
# 2019-05-09 200.72 34,908,607.00
# 2019-05-10 197.18 41,208,712.00
# 2019-05-13 185.72 57,430,623.00
# 2019-05-14 188.66 36,529,677.00
# 2019-05-15 190.92 26,544,718.00
# 2019-05-16 190.08 33,031,364.00
# 2019-05-17 189.00 32,879,090.00
# 2019-05-20 183.09 38,612,290.00
# 2019-05-21 186.60 28,364,848.00
# 2019-05-22 182.78 29,748,556.00
# 2019-05-23 179.66 36,529,736.00
# 2019-05-24 178.97 23,714,686.00
# 2019-05-28 178.23 27,948,160.00
# 2019-05-29 177.38 28,481,165.00
# 2019-05-30 178.30 21,218,412.00
# 2019-05-31 175.07 27,043,584.00
# 2019-06-03 173.30 40,396,069.00
# 2019-06-04 179.64 30,967,961.00
# 2019-06-05 182.54 29,773,427.00
# 2019-06-06 185.22 22,526,311.00
# 2019-06-07 190.15 30,684,393.00
# 2019-06-10 192.58 26,220,851.00
# 2019-06-11 194.81 26,932,882.00
# 2019-06-12 194.19 18,253,189.00
# 2019-06-13 194.15 21,674,625.00
# 2019-06-14 192.74 18,761,474.00
#
# [114 rows x 2 columns]

# %%
df.mean(axis=0)
# Out:
# close           181.12
# volume   30,380,586.43
# dtype: float64

# %%
import numpy as np # numpy universal functions can be applied to DataFrames
np.log(df) # e^output = original
# Out:
#             close  volume
# 2019-01-02   5.06   17.43
# 2019-01-03   4.96   18.33
# 2019-01-04   5.00   17.89
# 2019-01-07   5.00   17.82
# 2019-01-08   5.02   17.53
# 2019-01-09   5.03   17.62
# 2019-01-10   5.04   17.39
# 2019-01-11   5.03   17.11
# 2019-01-14   5.01   17.29
# 2019-01-15   5.03   17.17
# 2019-01-16   5.04   17.24
# 2019-01-17   5.05   17.21
# 2019-01-18   5.06   17.33
# 2019-01-22   5.03   17.23
# 2019-01-23   5.04   16.96
# 2019-01-24   5.03   17.05
# 2019-01-25   5.06   17.33
# 2019-01-28   5.05   17.08
# 2019-01-29   5.04   17.54
# 2019-01-30   5.11   17.93
# 2019-01-31   5.11   17.52
# 2019-02-01   5.12   17.30
# 2019-02-04   5.14   17.27
# 2019-02-05   5.16   17.40
# 2019-02-06   5.16   17.16
# 2019-02-07   5.14   17.27
# 2019-02-08   5.14   16.99
# 2019-02-11   5.13   16.86
# 2019-02-12   5.14   16.92
# 2019-02-13   5.14   16.93
# ...           ...     ...
# 2019-05-03   5.36   16.85
# 2019-05-06   5.34   17.29
# 2019-05-07   5.31   17.47
# 2019-05-08   5.31   17.09
# 2019-05-09   5.30   17.37
# 2019-05-10   5.28   17.53
# 2019-05-13   5.22   17.87
# 2019-05-14   5.24   17.41
# 2019-05-15   5.25   17.09
# 2019-05-16   5.25   17.31
# 2019-05-17   5.24   17.31
# 2019-05-20   5.21   17.47
# 2019-05-21   5.23   17.16
# 2019-05-22   5.21   17.21
# 2019-05-23   5.19   17.41
# 2019-05-24   5.19   16.98
# 2019-05-28   5.18   17.15
# 2019-05-29   5.18   17.16
# 2019-05-30   5.18   16.87
# 2019-05-31   5.17   17.11
# 2019-06-03   5.16   17.51
# 2019-06-04   5.19   17.25
# 2019-06-05   5.21   17.21
# 2019-06-06   5.22   16.93
# 2019-06-07   5.25   17.24
# 2019-06-10   5.26   17.08
# 2019-06-11   5.27   17.11
# 2019-06-12   5.27   16.72
# 2019-06-13   5.27   16.89
# 2019-06-14   5.26   16.75
#
# [114 rows x 2 columns]

# %%
# Let's visualize!
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'
# %matplotlib inline

# %%
df['10_avg'] = df['close'].rolling(10).mean()
df['20_avg'] = df['close'].rolling(20).mean()
df['strat'] = np.where(df['close'] > df['10_avg'], -1, 1)
avg_plot = pd.DataFrame((df['close'], df['10_avg'], df['20_avg']))
avg_plot = avg_plot.transpose()
avg_plot.plot(figsize=(20,12))

# %%
df['strat'].plot(kind='bar', figsize=(20,12))

# %%
# Now for Series, it's a vector
S = pd.Series(np.linspace(0, 15, 7), name='series')
S
# Out:
# 0    0.00
# 1    2.50
# 2    5.00
# 3    7.50
# 4   10.00
# 5   12.50
# 6   15.00
# Name: series, dtype: float64

# %%
series_df = pd.DataFrame()
series_df['No1'] = S # Assign a Series onto a DataFrame
series_df
# Out:
#     No1
# 0  0.00
# 1  2.50
# 2  5.00
# 3  7.50
# 4 10.00
# 5 12.50
# 6 15.00

# %%
directional_group = df.groupby('strat') # examine other factors influencing or strengthening current strat
directional_group.size()
# Out:
# strat
# -1    74
#  1    40
# dtype: int64
